# %%
import pandas as pd
import numpy as np
df = pd.read_excel('Data_melt.xlsx', sheet_name=None)

# %%
#Переименование column
df['01-31.01'].rename(columns = {'Химический состав' : df['01-31.01'].iat[0,6], 
                                 'Unnamed: 7' : df['01-31.01'].iat[0,7], 
                                 'Unnamed: 8' : df['01-31.01'].iat[0,8], 
                                 'Unnamed: 9' : df['01-31.01'].iat[0,9],
                                 'Unnamed: 10' : df['01-31.01'].iat[0,10],
                                 'Unnamed: 11' : df['01-31.01'].iat[0,11],
                                 'Unnamed: 12' : df['01-31.01'].iat[0,12],
                                 'Unnamed: 13' : df['01-31.01'].iat[0,13],
                                 'Unnamed: 14' : df['01-31.01'].iat[0,14],
                                 'Unnamed: 15' : df['01-31.01'].iat[0,15],
                                 'Unnamed: 16' : df['01-31.01'].iat[0,16],
                                 'Unnamed: 17' : df['01-31.01'].iat[0,17],
                                 'Unnamed: 18' : df['01-31.01'].iat[0,18],
                                 'Unnamed: 19' : df['01-31.01'].iat[0,19],
                                 'Unnamed: 20' : df['01-31.01'].iat[0,20],
                                 'Unnamed: 21' : df['01-31.01'].iat[0,21],
                                 'Unnamed: 22' : df['01-31.01'].iat[0,22],
                                 'Unnamed: 23' : df['01-31.01'].iat[0,23],
                                 'Unnamed: 24' : df['01-31.01'].iat[0,24],
                                 'Unnamed: 25' : df['01-31.01'].iat[0,25],
                                 'Unnamed: 26' : df['01-31.01'].iat[0,26],
                                 'Unnamed: 27' : df['01-31.01'].iat[0,27],
                                 'Unnamed: 28' : df['01-31.01'].iat[0,28],
                                 'Unnamed: 29' : df['01-31.01'].iat[0,29]
                                }, inplace = True)
df['01-31.01'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-31.01'] = df['01-31.01'].drop(index=[0])
df['01-31.01'] = df['01-31.01'].reset_index(drop=True)
df['01-31.01']['Date'] = '01.2022'
df['01-28.02'].rename(columns = {'Химический состав' : df['01-28.02'].iat[0,6], 
                                 'Unnamed: 7' : df['01-28.02'].iat[0,7], 
                                 'Unnamed: 8' : df['01-28.02'].iat[0,8], 
                                 'Unnamed: 9' : df['01-28.02'].iat[0,9],
                                 'Unnamed: 10' : df['01-28.02'].iat[0,10],
                                 'Unnamed: 11' : df['01-28.02'].iat[0,11],
                                 'Unnamed: 12' : df['01-28.02'].iat[0,12],
                                 'Unnamed: 13' : df['01-28.02'].iat[0,13],
                                 'Unnamed: 14' : df['01-28.02'].iat[0,14],
                                 'Unnamed: 15' : df['01-28.02'].iat[0,15],
                                 'Unnamed: 16' : df['01-28.02'].iat[0,16],
                                 'Unnamed: 17' : df['01-28.02'].iat[0,17],
                                 'Unnamed: 18' : df['01-28.02'].iat[0,18],
                                 'Unnamed: 19' : df['01-28.02'].iat[0,19],
                                 'Unnamed: 20' : df['01-28.02'].iat[0,20],
                                 'Unnamed: 21' : df['01-28.02'].iat[0,21],
                                 'Unnamed: 22' : df['01-28.02'].iat[0,22],
                                 'Unnamed: 23' : df['01-28.02'].iat[0,23],
                                 'Unnamed: 24' : df['01-28.02'].iat[0,24],
                                 'Unnamed: 25' : df['01-28.02'].iat[0,25],
                                 'Unnamed: 26' : df['01-28.02'].iat[0,26],
                                 'Unnamed: 27' : df['01-28.02'].iat[0,27],
                                 'Unnamed: 28' : df['01-28.02'].iat[0,28],
                                 'Unnamed: 29' : df['01-28.02'].iat[0,29]
                                }, inplace = True)
df['01-28.02'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-28.02'] = df['01-28.02'].drop(index=[0])
df['01-28.02'] = df['01-28.02'].reset_index(drop=True)
df['01-28.02']['Date'] = '02.2022'
df['01-31.03'].rename(columns = {'Химический состав' : df['01-31.03'].iat[0,6], 
                                 'Unnamed: 7' : df['01-31.03'].iat[0,7], 
                                 'Unnamed: 8' : df['01-31.03'].iat[0,8], 
                                 'Unnamed: 9' : df['01-31.03'].iat[0,9],
                                 'Unnamed: 10' : df['01-31.03'].iat[0,10],
                                 'Unnamed: 11' : df['01-31.03'].iat[0,11],
                                 'Unnamed: 12' : df['01-31.03'].iat[0,12],
                                 'Unnamed: 13' : df['01-31.03'].iat[0,13],
                                 'Unnamed: 14' : df['01-31.03'].iat[0,14],
                                 'Unnamed: 15' : df['01-31.03'].iat[0,15],
                                 'Unnamed: 16' : df['01-31.03'].iat[0,16],
                                 'Unnamed: 17' : df['01-31.03'].iat[0,17],
                                 'Unnamed: 18' : df['01-31.03'].iat[0,18],
                                 'Unnamed: 19' : df['01-31.03'].iat[0,19],
                                 'Unnamed: 20' : df['01-31.03'].iat[0,20],
                                 'Unnamed: 21' : df['01-31.03'].iat[0,21],
                                 'Unnamed: 22' : df['01-31.03'].iat[0,22],
                                 'Unnamed: 23' : df['01-31.03'].iat[0,23],
                                 'Unnamed: 24' : df['01-31.03'].iat[0,24],
                                 'Unnamed: 25' : df['01-31.03'].iat[0,25],
                                 'Unnamed: 26' : df['01-31.03'].iat[0,26],
                                 'Unnamed: 27' : df['01-31.03'].iat[0,27],
                                 'Unnamed: 28' : df['01-31.03'].iat[0,28],
                                 'Unnamed: 29' : df['01-31.03'].iat[0,29]
                                }, inplace = True)
df['01-31.03'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Ca                                 Ca
# Sb                                 Sb
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-31.03'] = df['01-31.03'].drop(index=[0])
df['01-31.03'] = df['01-31.03'].reset_index(drop=True)
df['01-31.03']['Date'] = '03.2022'
df['01-30.04'].rename(columns = {'Химический состав' : df['01-30.04'].iat[0,6], 
                                 'Unnamed: 7' : df['01-30.04'].iat[0,7], 
                                 'Unnamed: 8' : df['01-30.04'].iat[0,8], 
                                 'Unnamed: 9' : df['01-30.04'].iat[0,9],
                                 'Unnamed: 10' : df['01-30.04'].iat[0,10],
                                 'Unnamed: 11' : df['01-30.04'].iat[0,11],
                                 'Unnamed: 12' : df['01-30.04'].iat[0,12],
                                 'Unnamed: 13' : df['01-30.04'].iat[0,13],
                                 'Unnamed: 14' : df['01-30.04'].iat[0,14],
                                 'Unnamed: 15' : df['01-30.04'].iat[0,15],
                                 'Unnamed: 16' : df['01-30.04'].iat[0,16],
                                 'Unnamed: 17' : df['01-30.04'].iat[0,17],
                                 'Unnamed: 18' : df['01-30.04'].iat[0,18],
                                 'Unnamed: 19' : df['01-30.04'].iat[0,19],
                                 'Unnamed: 20' : df['01-30.04'].iat[0,20],
                                 'Unnamed: 21' : df['01-30.04'].iat[0,21],
                                 'Unnamed: 22' : df['01-30.04'].iat[0,22],
                                 'Unnamed: 23' : df['01-30.04'].iat[0,23],
                                 'Unnamed: 24' : df['01-30.04'].iat[0,24],
                                 'Unnamed: 25' : df['01-30.04'].iat[0,25],
                                 'Unnamed: 26' : df['01-30.04'].iat[0,26],
                                 'Unnamed: 27' : df['01-30.04'].iat[0,27],
                                 'Unnamed: 28' : df['01-30.04'].iat[0,28],
                                 'Unnamed: 29' : df['01-30.04'].iat[0,29]
                                }, inplace = True)
df['01-30.04'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Ca                                 Ca
# Sb                                 Sb
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-30.04'] = df['01-30.04'].drop(index=[0])
df['01-30.04'] = df['01-30.04'].reset_index(drop=True)
df['01-30.04']['Date'] = '04.2022'
df['01-31.05'].rename(columns = {'Химический состав' : df['01-31.05'].iat[0,6], 
                                 'Unnamed: 7' : df['01-31.05'].iat[0,7], 
                                 'Unnamed: 8' : df['01-31.05'].iat[0,8], 
                                 'Unnamed: 9' : df['01-31.05'].iat[0,9],
                                 'Unnamed: 10' : df['01-31.05'].iat[0,10],
                                 'Unnamed: 11' : df['01-31.05'].iat[0,11],
                                 'Unnamed: 12' : df['01-31.05'].iat[0,12],
                                 'Unnamed: 13' : df['01-31.05'].iat[0,13],
                                 'Unnamed: 14' : df['01-31.05'].iat[0,14],
                                 'Unnamed: 15' : df['01-31.05'].iat[0,15],
                                 'Unnamed: 16' : df['01-31.05'].iat[0,16],
                                 'Unnamed: 17' : df['01-31.05'].iat[0,17],
                                 'Unnamed: 18' : df['01-31.05'].iat[0,18],
                                 'Unnamed: 19' : df['01-31.05'].iat[0,19],
                                 'Unnamed: 20' : df['01-31.05'].iat[0,20],
                                 'Unnamed: 21' : df['01-31.05'].iat[0,21],
                                 'Unnamed: 22' : df['01-31.05'].iat[0,22],
                                 'Unnamed: 23' : df['01-31.05'].iat[0,23],
                                 'Unnamed: 24' : df['01-31.05'].iat[0,24],
                                 'Unnamed: 25' : df['01-31.05'].iat[0,25],
                                 'Unnamed: 26' : df['01-31.05'].iat[0,26],
                                 'Unnamed: 27' : df['01-31.05'].iat[0,27],
                                 'Unnamed: 28' : df['01-31.05'].iat[0,28],
                                 'Unnamed: 29' : df['01-31.05'].iat[0,29]
                                }, inplace = True)
df['01-31.05'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Ca                                 Ca
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-31.05'] = df['01-31.05'].drop(index=[0])
df['01-31.05'] = df['01-31.05'].reset_index(drop=True)
df['01-31.05']['Date'] = '05.2022'
df['01-30.06'].rename(columns = {'Химический состав' : df['01-30.06'].iat[0,6], 
                                 'Unnamed: 7' : df['01-30.06'].iat[0,7], 
                                 'Unnamed: 8' : df['01-30.06'].iat[0,8], 
                                 'Unnamed: 9' : df['01-30.06'].iat[0,9],
                                 'Unnamed: 10' : df['01-30.06'].iat[0,10],
                                 'Unnamed: 11' : df['01-30.06'].iat[0,11],
                                 'Unnamed: 12' : df['01-30.06'].iat[0,12],
                                 'Unnamed: 13' : df['01-30.06'].iat[0,13],
                                 'Unnamed: 14' : df['01-30.06'].iat[0,14],
                                 'Unnamed: 15' : df['01-30.06'].iat[0,15],
                                 'Unnamed: 16' : df['01-30.06'].iat[0,16],
                                 'Unnamed: 17' : df['01-30.06'].iat[0,17],
                                 'Unnamed: 18' : df['01-30.06'].iat[0,18],
                                 'Unnamed: 19' : df['01-30.06'].iat[0,19],
                                 'Unnamed: 20' : df['01-30.06'].iat[0,20],
                                 'Unnamed: 21' : df['01-30.06'].iat[0,21],
                                 'Unnamed: 22' : df['01-30.06'].iat[0,22],
                                 'Unnamed: 23' : df['01-30.06'].iat[0,23],
                                 'Unnamed: 24' : df['01-30.06'].iat[0,24],
                                 'Unnamed: 25' : df['01-30.06'].iat[0,25],
                                 'Unnamed: 26' : df['01-30.06'].iat[0,26],
                                 'Unnamed: 27' : df['01-30.06'].iat[0,27],
                                 'Unnamed: 28' : df['01-30.06'].iat[0,28],
                                 'Unnamed: 29' : df['01-30.06'].iat[0,29]
                                }, inplace = True)
df['01-30.06'].iloc[0]
# Out:
# Дата отгрузки                     NaN
# № вагона/Сертификат качества      NaN
# № плавки                          NaN
# Сечение                           NaN
# Марка стали                       NaN
# Тех карта                         NaN
# O                                   O
# Ca                                 Ca
# Sb                                 Sb
# Pb                                 Pb
# Nb                                 Nb
# C                                   C
# Si                                 Si
# Mn                                 Mn
# P                                   P
# S                                   S
# Ni                                 Ni
# Cr                                 Cr
# Cu                                 Cu
# Al                                 Al
# As                                 As
# N                                   N
# Mo                                 Mo
# V                                   V
# B                                   B
# Sn                                 Sn
# Ceq                               Ceq
# Sn+Mo                           Sn+Mo
# Ti                                 Ti
# W                                   W
# Вес                               NaN
# Примечание                        NaN
# Name: 0, dtype: object

# %%
df['01-30.06'] = df['01-30.06'].drop(index=[0])
df['01-30.06'] = df['01-30.06'].reset_index(drop=True)
df['01-30.06']['Date'] = '06.2022'
df_melt = pd.concat ([df['01-31.01'], df['01-28.02'], df['01-31.03'], df['01-30.04'], df['01-31.05'], df['01-30.06']],ignore_index=True)

# %%
df_melt["Дата отгрузки"] = df_melt["Дата отгрузки"].fillna(method="bfill")
df_melt.drop(df_melt.index[-1], axis=0, inplace=True)
df_melt = df_melt.astype({'Дата отгрузки' : 'int64', '№ плавки' : 'int64'})
df_melt = df_melt.astype({'O' : 'float64', 'Pb' : 'float64', 'Nb' : 'float64', 'C' : 'float64', 'Si' : 'float64', 'Mn' : 'float64', 'P' : 'float64', 'S' : 'float64',
       'Ni' : 'float64', 'Cr' : 'float64', 'Cu' : 'float64', 'Al' : 'float64', 'As' : 'float64', 'N' : 'float64', 'Mo' : 'float64', 'V' : 'float64', 'B' : 'float64', 'Sn' : 'float64', 'Ceq' : 'float64', 'Sn+Mo' : 'float64',
       'Ti' : 'float64', 'W' : 'float64', 'Ca' : 'float64', 'Sb' : 'float64', 'Вес' : 'float64',})
df_melt.reset_index(drop=True)
df_melt.info(verbose=True)
df_melt["Дата отгрузки"].isna()
df_melt.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13137 entries, 0 to 13136
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Дата отгрузки                 13137 non-null  int64
#  1   № вагона/Сертификат качества  9215 non-null   object
#  2   № плавки                      13137 non-null  int64
#  3   Сечение                       13137 non-null  object
#  4   Марка стали                   13137 non-null  object
#  5   Тех карта                     13137 non-null  object
#  6   O                             0 non-null      float64
#  7   Pb                            12423 non-null  float64
#  8   Nb                            3011 non-null   float64
#  9   C                             13125 non-null  float64
#  10  Si                            13125 non-null  float64
#  11  Mn                            13125 non-null  float64
#  12  P                             13120 non-null  float64
#  13  S                             13120 non-null  float64
#  14  Ni                            13120 non-null  float64
#  15  Cr                            13120 non-null  float64
#  16  Cu                            13120 non-null  float64
#  17  Al                            13112 non-null  float64
#  18  As                            13118 non-null  float64
#  19  N                             13070 non-null  float64
#  20  Mo                            12511 non-null  float64
#  21  V                             12507 non-null  float64
#  22  B                             12476 non-null  float64
#  23  Sn                            12395 non-null  float64
#  24  Ceq                           6184 non-null   float64
#  25  Sn+Mo                         0 non-null      float64
#  26  Ti                            12416 non-null  float64
#  27  W                             12433 non-null  float64
#  28  Вес                           13137 non-null  float64
#  29  Примечание                    13137 non-null  object
#  30  Date                          13137 non-null  object
#  31  Ca                            8102 non-null   float64
#  32  Sb                            6196 non-null   float64
# dtypes: float64(25), int64(2), object(6)
# memory usage: 3.4+ MB
# Index(['Дата отгрузки', '№ вагона/Сертификат качества', '№ плавки', 'Сечение',
#        'Марка стали', 'Тех карта', 'O', 'Pb', 'Nb', 'C', 'Si', 'Mn', 'P', 'S',
#        'Ni', 'Cr', 'Cu', 'Al', 'As', 'N', 'Mo', 'V', 'B', 'Sn', 'Ceq', 'Sn+Mo',
#        'Ti', 'W', 'Вес', 'Примечание', 'Date', 'Ca', 'Sb'],
#       dtype='object')

# %%
df_melt = df_melt.fillna(value = 0)

# %%
df_melt = df_melt.replace(0, np.nan)

# %%
df_melt.drop(['Дата отгрузки', '№ вагона/Сертификат качества', 'Сечение',
              'Тех карта', 'Вес', 'Примечание', 'Date',], axis = 1, inplace = True)

# %%
df_melt.sort_values(by=['№ плавки'])
# Out:
#        № плавки Марка стали   O     Pb     Nb     C    Si    Mn      P      S  \
# 1586    2117682       СТ3СП NaN  0.002    NaN  0.23  0.57  1.48  0.026  0.022
# 1409    2117682       СТ3СП NaN  0.002    NaN  0.23  0.57  1.48  0.026  0.022
# 1309    2117682       СТ3СП NaN  0.002    NaN  0.23  0.57  1.48  0.026  0.022
# 618     2127488       СТ3СП NaN    NaN  0.001  0.19  0.21  0.61  0.017  0.032
# 2178    2127586       СТ3СП NaN    NaN    NaN  0.21  0.19  0.73  0.017  0.024
# ...         ...         ...  ..    ...    ...   ...   ...   ...    ...    ...
# 11874   2232387    Сталь 80 NaN    NaN    NaN  0.84  0.18  0.52  0.004  0.005
# 11727   2232387    Сталь 80 NaN    NaN    NaN  0.84  0.18  0.52  0.004  0.005
# 11860   2232388    SAE 1005 NaN    NaN    NaN  0.05  0.04  0.28  0.011  0.013
# 11876   2232388    SAE 1005 NaN    NaN    NaN  0.05  0.04  0.28  0.011  0.013
# 11730   2232388    SAE 1005 NaN    NaN    NaN  0.05  0.04  0.28  0.011  0.013
#
#        ...     Mo       V   B     Sn   Ceq  Sn+Mo     Ti      W  Ca  Sb
# 1586   ...  0.014  0.0025 NaN  0.009  0.52    NaN  0.001  0.003 NaN NaN
# 1409   ...  0.014  0.0025 NaN  0.009  0.52    NaN  0.001  0.003 NaN NaN
# 1309   ...  0.014  0.0025 NaN  0.009  0.52    NaN  0.001  0.003 NaN NaN
# 618    ...  0.013  0.0013 NaN  0.009  0.33    NaN  0.001  0.002 NaN NaN
# 2178   ...  0.014  0.0028 NaN  0.010  0.38    NaN  0.001  0.006 NaN NaN
# ...    ...    ...     ...  ..    ...   ...    ...    ...    ...  ..  ..
# 11874  ...    NaN     NaN NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 11727  ...    NaN     NaN NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 11860  ...  0.010  0.0006 NaN    NaN  0.13    NaN    NaN    NaN NaN NaN
# 11876  ...  0.010  0.0006 NaN    NaN  0.13    NaN    NaN    NaN NaN NaN
# 11730  ...  0.010  0.0006 NaN    NaN  0.13    NaN    NaN    NaN NaN NaN
#
# [13137 rows x 26 columns]

# %%
df_melt.drop_duplicates(inplace = True)

# %%
df_melt.set_index('№ плавки',drop = False)
# Out:
#           № плавки Марка стали   O  Pb  Nb     C    Si    Mn      P      S  \
# № плавки
# 2220542    2220542     СВ08Г2С NaN NaN NaN  0.07  0.75  1.82  0.007  0.009
# 2127609    2127609    Сталь 80 NaN NaN NaN  0.84  0.17  0.57  0.004  0.010
# 2127611    2127611    Сталь 80 NaN NaN NaN  0.84  0.17  0.56  0.004  0.007
# 2127607    2127607    Сталь 80 NaN NaN NaN  0.83  0.16  0.55  0.004  0.009
# 2220041    2220041    Сталь 70 NaN NaN NaN  0.74  0.17  0.47  0.004  0.007
# ...            ...         ...  ..  ..  ..   ...   ...   ...    ...    ...
# 2232360    2232360        А240 NaN NaN NaN  0.20  0.18  0.57  0.015  0.016
# 2231165    2231165        А240 NaN NaN NaN  0.21  0.18  0.56  0.027  0.020
# 2223621    2223621       СТ1ПС NaN NaN NaN  0.10  0.08  0.38  0.011  0.016
# 2223644    2223644       СТ1СП NaN NaN NaN  0.06  0.16  0.48  0.013  0.013
# 2232362    2232362        А240 NaN NaN NaN  0.12  0.13  0.44  0.018  0.016
#
#           ...     Mo       V      B     Sn   Ceq  Sn+Mo      Ti      W     Ca  \
# № плавки  ...
# 2220542   ...  0.010  0.0010  0.005  0.006   NaN    NaN  0.0010  0.001    NaN
# 2127609   ...  0.006  0.0006    NaN  0.001  0.89    NaN  0.0012  0.001    NaN
# 2127611   ...  0.009  0.0004    NaN  0.001  0.89    NaN  0.0011  0.001    NaN
# 2127607   ...  0.004  0.0003    NaN  0.001  0.87    NaN  0.0011  0.002    NaN
# 2220041   ...  0.003  0.0003    NaN  0.001   NaN    NaN  0.0009  0.002    NaN
# ...       ...    ...     ...    ...    ...   ...    ...     ...    ...    ...
# 2232360   ...    NaN     NaN    NaN    NaN   NaN    NaN     NaN    NaN    NaN
# 2231165   ...    NaN     NaN    NaN    NaN   NaN    NaN     NaN    NaN    NaN
# 2223621   ...    NaN     NaN  0.002    NaN   NaN    NaN     NaN    NaN    NaN
# 2223644   ...  0.018  0.0005  0.002  0.011   NaN    NaN  0.0009  0.002  0.001
# 2232362   ...    NaN     NaN    NaN    NaN   NaN    NaN     NaN    NaN    NaN
#
#              Sb
# № плавки
# 2220542     NaN
# 2127609     NaN
# 2127611     NaN
# 2127607     NaN
# 2220041     NaN
# ...         ...
# 2232360     NaN
# 2231165     NaN
# 2223621     NaN
# 2223644   0.002
# 2232362     NaN
#
# [4087 rows x 26 columns]

# %%
df = pd.read_excel('Data_wire_rod.xlsx', sheet_name=None)
df['катанка'].rename(columns = {'Unnamed: 0' : 'ИМЯ','Unnamed: 5' : 'ПЛАВКА','Unnamed: 6' : 'СТАЛЬ','Unnamed: 7' : 'НД','Unnamed: 8' : 'Dном, мм','Unnamed: 9' : 'Dфак, мм','Unnamed: 10' : 'σв, Н/мм2','Unnamed: 11' : 'σт, Н/мм2','Unnamed: 12' : 'σв/σт','Unnamed: 13' : 'δmax, %','Unnamed: 14' : 'Ψ,%','Unnamed: 15' : 'δ5, %','Unnamed: 16' : 'δ10, %','Unnamed: 17' : 'окалина, %','Unnamed: 18' : 'Изгиб','Unnamed: 19' : 'осадка','Unnamed: 20' : 'перегиб','Unnamed: 21' : 'ПРИМ','Unnamed: 22' : 'ДАТА','Unnamed: 23' : 'ЦЕЛЬ','Unnamed: 24' : 'оператор','Unnamed: 25' : 'протокол','Unnamed: 26' : '№заказа','Unnamed: 27' : 'σв, МПа','Unnamed: 28' : 'Ψ, %','Unnamed: 29' : 'окалина','Unnamed: 30' : 'овал','Unnamed: 31' : 'Бригада №','Unnamed: 32' : 'Приложение по выплавке',}, inplace = True)
df['катанка'] = df['катанка'].drop(index=[0, 1, 2])
df['катанка'] = df['катанка'].reset_index(drop=True)
df_wire_rod = df['катанка']
df_wire_rod.columns
# Out:
# Index(['ИМЯ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'ПЛАВКА',
#        'СТАЛЬ', 'НД', 'Dном, мм', 'Dфак, мм', 'σв, Н/мм2', 'σт, Н/мм2',
#        'σв/σт', 'δmax, %', 'Ψ,%', 'δ5, %', 'δ10, %', 'окалина, %', 'Изгиб',
#        'осадка', 'перегиб', 'ПРИМ', 'ДАТА', 'ЦЕЛЬ', 'оператор', 'протокол',
#        '№заказа', 'σв, МПа', 'Ψ, %', 'окалина', 'овал', 'Бригада №',
#        'Приложение по выплавке', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39',
#        'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45'],
#       dtype='object')

# %%
df_wire = pd.read_excel('Data_wire.xlsx', sheet_name=None)
df_wire['неоц'].rename(columns = {'ИМЯ' : 'стан', 'Unnamed: 2' : 'бухта', 'Unnamed: 3': '№', 'повторы' : 'σв', 'Unnamed: 21' : 'δ' }, inplace = True)
df_wire['неоц'].drop(['Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'], axis = 1, inplace = True)
df_wire['неоц'] = df_wire['неоц'].drop(index=[0])
df_wire['неоц'] = df_wire['неоц'].reset_index(drop=True)
df_wire = df_wire['неоц']
df_wire.head(3)
# Out:
#   Бр-изготовитель стан бухта  №   плавка  сталь  \
# 0               4    8     1  1  2127037  15Гпс
# 1               4    7     1  1  2127037  15Гпс
# 2               4    6     1  1  2127037  15Гпс
#
#                                        НД Т/О  Dном Dфакт  ... σв  δ  \
# 0  ТК 55798700-BR-18.9-001/(001,005)-0020  ХВ  2.83  2.81  ...  -  -
# 1  ТК 55798700-BR-18.9-001/(001,005)-0020  ХВ  2.83  2.81  ...  -  -
# 2  ТК 55798700-BR-18.9-001/(001,005)-0020  ХВ  2.83  2.81  ...  -  -
#
#   № бригады Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34  \
# 0         4         NaN         NaN         NaN         NaN         NaN
# 1         4         NaN         NaN         NaN         NaN         NaN
# 2         4         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 35 Unnamed: 36
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
#
# [3 rows x 30 columns]

# %%
df_wire_rod = df_wire_rod [['ПЛАВКА', 'ИМЯ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'СТАЛЬ', 'НД', 'Dном, мм', 'Dфак, мм', 'σв, Н/мм2', 'σт, Н/мм2',
       'σв/σт', 'δmax, %', 'Ψ,%', 'δ5, %', 'δ10, %', 'окалина, %', 'Изгиб',
       'осадка', 'перегиб', 'ПРИМ', 'ДАТА', 'ЦЕЛЬ', 'оператор', 'протокол',
       '№заказа', 'σв, МПа', 'Ψ, %', 'окалина', 'овал', 'Бригада №',
       'Приложение по выплавке']]
df_wire_rod.rename(columns = {'ПЛАВКА' : '№ плавки'}, inplace = True)
df_wire_rod.rename(columns = {'ИМЯ' : '№ образца'}, inplace = True)
df_wire_rod.rename(columns = {'Unnamed: 1' : 'Линия проката'}, inplace = True)
df_wire_rod.rename(columns = {'Unnamed: 3' : 'Начало/конец образца'}, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_wire_rod.loc[(df_wire_rod['№ плавки'] == "222160*9"), '№ плавки'] = "-"
df_wire_rod = df_wire_rod.loc[df_wire_rod['№ плавки'] != "-"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_wire_rod = df_wire_rod.astype({'№ плавки' : 'int64'})
df_wire_rod = df_wire_rod.astype({'Unnamed: 4' : 'object'})

# %%
df_melt.set_index('№ плавки', drop=True, append=False, inplace=True, verify_integrity=False)
df_melt.head(5)
# Out:
#          Марка стали   O  Pb  Nb     C    Si    Mn      P      S    Ni  ...  \
# № плавки                                                                ...
# 2220542      СВ08Г2С NaN NaN NaN  0.07  0.75  1.82  0.007  0.009  0.08  ...
# 2127609     Сталь 80 NaN NaN NaN  0.84  0.17  0.57  0.004  0.010  0.05  ...
# 2127611     Сталь 80 NaN NaN NaN  0.84  0.17  0.56  0.004  0.007  0.06  ...
# 2127607     Сталь 80 NaN NaN NaN  0.83  0.16  0.55  0.004  0.009  0.05  ...
# 2220041     Сталь 70 NaN NaN NaN  0.74  0.17  0.47  0.004  0.007  0.07  ...
#
#              Mo       V      B     Sn   Ceq  Sn+Mo      Ti      W  Ca  Sb
# № плавки
# 2220542   0.010  0.0010  0.005  0.006   NaN    NaN  0.0010  0.001 NaN NaN
# 2127609   0.006  0.0006    NaN  0.001  0.89    NaN  0.0012  0.001 NaN NaN
# 2127611   0.009  0.0004    NaN  0.001  0.89    NaN  0.0011  0.001 NaN NaN
# 2127607   0.004  0.0003    NaN  0.001  0.87    NaN  0.0011  0.002 NaN NaN
# 2220041   0.003  0.0003    NaN  0.001   NaN    NaN  0.0009  0.002 NaN NaN
#
# [5 rows x 25 columns]

# %%
df_melt_df_wire_rod = df_wire_rod.join(df_melt, on="№ плавки")
df_melt_df_wire_rod = pd.merge(df_wire_rod, df_melt, left_on="№ плавки", right_index=True, how="left", sort=False)
df_melt_df_wire_rod.info(verbose=True)
df_melt_df_wire_rod.to_excel("df_melt_df_wire_rod.xlsx")
df_melt_df_wire_rod.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9762 entries, 0 to 9789
# Data columns (total 58 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   № плавки                9762 non-null   int64
#  1   № образца               9762 non-null   object
#  2   Линия проката           9762 non-null   object
#  3   Unnamed: 2              9762 non-null   object
#  4   Начало/конец образца    9762 non-null   object
#  5   Unnamed: 4              9762 non-null   object
#  6   СТАЛЬ                   9762 non-null   object
#  7   НД                      9762 non-null   object
#  8   Dном, мм                9762 non-null   object
#  9   Dфак, мм                9762 non-null   object
#  10  σв, Н/мм2               9762 non-null   object
#  11  σт, Н/мм2               9762 non-null   object
#  12  σв/σт                   9762 non-null   object
#  13  δmax, %                 9762 non-null   object
#  14  Ψ,%                     9762 non-null   object
#  15  δ5, %                   9762 non-null   object
#  16  δ10, %                  9762 non-null   object
#  17  окалина, %              9762 non-null   object
#  18  Изгиб                   9762 non-null   object
#  19  осадка                  9762 non-null   object
#  20  перегиб                 9762 non-null   object
#  21  ПРИМ                    9762 non-null   object
#  22  ДАТА                    9762 non-null   object
#  23  ЦЕЛЬ                    9762 non-null   object
#  24  оператор                9762 non-null   object
#  25  протокол                9762 non-null   object
#  26  №заказа                 9762 non-null   object
#  27  σв, МПа                 9762 non-null   object
#  28  Ψ, %                    9762 non-null   object
#  29  окалина                 9762 non-null   object
#  30  овал                    9762 non-null   object
#  31  Бригада №               9762 non-null   object
#  32  Приложение по выплавке  9762 non-null   object
#  33  Марка стали             8716 non-null   object
#  34  O                       0 non-null      float64
#  35  Pb                      762 non-null    float64
#  36  Nb                      22 non-null     float64
#  37  C                       8714 non-null   float64
#  38  Si                      8714 non-null   float64
#  39  Mn                      8714 non-null   float64
#  40  P                       8714 non-null   float64
#  41  S                       8714 non-null   float64
#  42  Ni                      8714 non-null   float64
#  43  Cr                      8714 non-null   float64
#  44  Cu                      8714 non-null   float64
#  45  Al                      8710 non-null   float64
#  46  As                      8714 non-null   float64
#  47  N                       8694 non-null   float64
#  48  Mo                      8400 non-null   float64
#  49  V                       8398 non-null   float64
#  50  B                       3142 non-null   float64
#  51  Sn                      8408 non-null   float64
#  52  Ceq                     2436 non-null   float64
#  53  Sn+Mo                   0 non-null      float64
#  54  Ti                      8324 non-null   float64
#  55  W                       8378 non-null   float64
#  56  Ca                      4909 non-null   float64
#  57  Sb                      3934 non-null   float64
# dtypes: float64(24), int64(1), object(33)
# memory usage: 4.4+ MB
# Index(['№ плавки', '№ образца', 'Линия проката', 'Unnamed: 2',
#        'Начало/конец образца', 'Unnamed: 4', 'СТАЛЬ', 'НД', 'Dном, мм',
#        'Dфак, мм', 'σв, Н/мм2', 'σт, Н/мм2', 'σв/σт', 'δmax, %', 'Ψ,%',
#        'δ5, %', 'δ10, %', 'окалина, %', 'Изгиб', 'осадка', 'перегиб', 'ПРИМ',
#        'ДАТА', 'ЦЕЛЬ', 'оператор', 'протокол', '№заказа', 'σв, МПа', 'Ψ, %',
#        'окалина', 'овал', 'Бригада №', 'Приложение по выплавке', 'Марка стали',
#        'O', 'Pb', 'Nb', 'C', 'Si', 'Mn', 'P', 'S', 'Ni', 'Cr', 'Cu', 'Al',
#        'As', 'N', 'Mo', 'V', 'B', 'Sn', 'Ceq', 'Sn+Mo', 'Ti', 'W', 'Ca', 'Sb'],
#       dtype='object')

# %%
df_melt_df_wire_rod['СТАЛЬ'].unique()
# Out:
# array(['Ст1пс', 'SAE 1005', 'Ст1сп', 'Ст3сп', 'Св-08Г2С', '15пс',
#        'SAE 1006', 'Св-08А', 'SAE 1004', 'ТМ', 'Ст4сп', 80, 70, '15Гпс',
#        'Св-08АА', 'Св-08ГА', 'Св-08ГС', 'Св-08ГНМ', 'Ст0', 'SAE 1008', 65,
#        'Св-10НМА', 10, 'Св-08ГСМТ', 'C9D', '75', 'Cт1пс', 'С1сп', 'S2Mo',
#        'SAE 1015', '-', 'SAE 1010', 'SAE 1045', '30Г1Р', '20Г2Р',
#        'SAE 1018', 'Св-10ГСМТ', 'Св-10ХГ2СМФ', 'SAE 1022', '3Si1 (SG2)',
#        '20Г1Р', 'Ст 0', '3Si1', 20, 'Ст1кп', 'Ст3пс', '20КП', 'S1',
#        'S1-HQ', '20кп ', '20кп', 'S1-HQ ', '3Si1 ', 'SAE 1005В',
#        'SAE 1005B'], dtype=object)

# %%
df_melt_df_wire_rod_15Gps = df_melt_df_wire_rod[df_melt_df_wire_rod['СТАЛЬ'] == '15Гпс']

# %%
df_melt_df_wire_rod['Dном, мм'].unique()
# Out:
# array([7, 5.5, 9, 6.5, '6,5', 6, 10, 8, 12, 11, 13, 9.5, 7.5, 10.5, 8.5,
#        21, 17, 2.83, 2.8], dtype=object)

# %%
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps[df_melt_df_wire_rod_15Gps['Dном, мм'] == 5.5]

# %%
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.loc[df_melt_df_wire_rod_15Gps_5_5_diam['σв, Н/мм2'] != "-"]
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.astype({'σв, Н/мм2' : 'float64'})
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.loc[df_melt_df_wire_rod_15Gps_5_5_diam['Ψ,%'] != "-"]
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.astype({'Ψ,%' : 'float64'})

# %%
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.dropna(axis=0, how='any', subset=['C'])

# %%
np.cov(df_melt_df_wire_rod_15Gps_5_5_diam['σв, Н/мм2'],df_melt_df_wire_rod_15Gps_5_5_diam['C'])
# Out:
# array([[2.78464819e+02, 8.98776793e-03],
#        [8.98776793e-03, 3.05474133e-05]])

# %%
df_melt_df_wire_rod_15Gps_5_5_diam.describe()
# Out:
#            № плавки   σв, Н/мм2         Ψ,%    O     Pb        Nb           C  \
# count  1.340000e+02  134.000000  134.000000  0.0  4.000  6.000000  134.000000
# mean   2.221635e+06  497.611940   68.888060  NaN  0.001  0.036667    0.181642
# std    9.608281e+02   16.687265    2.002481  NaN  0.000  0.005164    0.005527
# min    2.220134e+06  465.000000   63.000000  NaN  0.001  0.030000    0.170000
# 25%    2.220982e+06  485.000000   68.000000  NaN  0.001  0.032500    0.180000
# 50%    2.221536e+06  497.500000   69.000000  NaN  0.001  0.040000    0.180000
# 75%    2.222274e+06  510.000000   70.000000  NaN  0.001  0.040000    0.185000
# max    2.223232e+06  560.000000   73.000000  NaN  0.001  0.040000    0.190000
#
#                Si          Mn           P  ...          Mo           V  \
# count  134.000000  134.000000  134.000000  ...  134.000000  134.000000
# mean     0.082582    0.752537    0.006299  ...    0.009672    0.000584
# std      0.010413    0.010977    0.001055  ...    0.003190    0.000560
# min      0.050000    0.720000    0.004000  ...    0.006000    0.000300
# 25%      0.080000    0.750000    0.006000  ...    0.008000    0.000300
# 50%      0.080000    0.750000    0.006000  ...    0.009000    0.000300
# 75%      0.090000    0.760000    0.007000  ...    0.011000    0.000700
# max      0.100000    0.780000    0.009000  ...    0.022000    0.003500
#
#                 B          Sn         Ceq  Sn+Mo          Ti           W  \
# count  134.000000  134.000000  128.000000    0.0  134.000000  134.000000
# mean     0.003567    0.005642    0.294062    NaN    0.001188    0.001313
# std      0.000527    0.001235    0.037761    NaN    0.000422    0.000466
# min      0.003000    0.003000    0.220000    NaN    0.000800    0.001000
# 25%      0.003000    0.005000    0.270000    NaN    0.001000    0.001000
# 50%      0.004000    0.006000    0.290000    NaN    0.001100    0.001000
# 75%      0.004000    0.006000    0.312500    NaN    0.001200    0.002000
# max      0.005000    0.010000    0.400000    NaN    0.003500    0.002000
#
#               Ca         Sb
# count  86.000000  58.000000
# mean    0.002302   0.001966
# std     0.000510   0.000772
# min     0.001000   0.001000
# 25%     0.002000   0.001000
# 50%     0.002000   0.002000
# 75%     0.003000   0.002000
# max     0.003000   0.004000
#
# [8 rows x 27 columns]

# %%
df_melt_df_wire_rod_15Gps_5_5_diam.corrwith(df_melt_df_wire_rod_15Gps_5_5_diam['σв, Н/мм2'])
# Out:
# № плавки    -0.491351
# σв, Н/мм2    1.000000
# Ψ,%          0.069567
# O                 NaN
# Pb                NaN
# Nb          -0.649519
# C            0.097449
# Si           0.426707
# Mn          -0.148307
# P            0.230826
# S            0.374130
# Ni           0.423558
# Cr           0.126815
# Cu           0.399164
# Al          -0.020020
# As           0.023831
# N           -0.179135
# Mo           0.355909
# V            0.155568
# B           -0.058606
# Sn           0.469005
# Ceq          0.105473
# Sn+Mo             NaN
# Ti           0.041783
# W            0.377676
# Ca           0.003316
# Sb           0.076409
# dtype: float64

# %%
df_melt_df_wire_rod_15Gps_5_5_diam.corrwith(df_melt_df_wire_rod_15Gps_5_5_diam['Ψ,%'])
# Out:
# № плавки    -0.153886
# σв, Н/мм2    0.069567
# Ψ,%          1.000000
# O                 NaN
# Pb                NaN
# Nb          -0.357295
# C           -0.114384
# Si           0.029111
# Mn          -0.081390
# P            0.019493
# S           -0.097620
# Ni           0.082078
# Cr           0.077623
# Cu          -0.072056
# Al           0.022066
# As          -0.054081
# N            0.094179
# Mo           0.064822
# V           -0.023790
# B           -0.131830
# Sn          -0.116679
# Ceq         -0.044530
# Sn+Mo             NaN
# Ti          -0.101127
# W            0.005657
# Ca          -0.007337
# Sb           0.163795
# dtype: float64

# %%
df_melt_df_wire_rod_15Gps_5_5_diam = df_melt_df_wire_rod_15Gps_5_5_diam.dropna(axis=0, how='any', subset=['C'])

# %%
import matplotlib.pyplot as plt
plt.scatter(df_melt_df_wire_rod_15Gps_5_5_diam['Si'] ,df_melt_df_wire_rod_15Gps_5_5_diam['σв, Н/мм2'] , color = 'r')
plt.xlabel('Si, %')
plt.ylabel('σв, Н/мм2')
# Out:
# Text(0, 0.5, 'σв, Н/мм2')

# %%
import seaborn as sns
cols = ['σв, Н/мм2', 'Ψ,%', 'Si', 'Ni', 'Sn', 'Nb']
sns.heatmap(df_melt_df_wire_rod_15Gps_5_5_diam[cols].corr(),
            cbar=True,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
cols = ['σв, Н/мм2', 'Si']
df_LR = df_melt_df_wire_rod_15Gps_5_5_diam[cols]
df_LR.shape
# Out:
# (134, 2)

# %%
X = df_LR[['Si']]
y = df_LR[['σв, Н/мм2']]
reg = LinearRegression().fit(X, y)
reg
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, reg.predict(X), color = 'blue')
plt.xlabel(cols[-1:])
plt.ylabel(cols[:-1])
plt.show()
